# %% [markdown]
# <a href="https://colab.research.google.com/github/ImAzazel33/Deep-Learning/blob/main/Stochastic%20Gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# Add bias term to input features
X_b = np.c_[np.ones((100, 1)), X]

# Initialize parameters
eta = 0.01  # Learning rate
n_epochs = 1000

# Initialize theta randomly
theta = np.random.randn(2, 1)

# Stochastic Gradient Descent
for epoch in range(n_epochs):
    for i in range(len(X)):
        random_index = np.random.randint(len(X))
        xi = X_b[random_index:random_index+1]
        yi = y[random_index:random_index+1]
        gradients = -2 * xi.T.dot(yi - xi.dot(theta))
        theta = theta - eta * gradients

# Predictions
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_pred = X_new_b.dot(theta)

# Plotting
plt.plot(X, y, "b.")
plt.plot(X_new, y_pred, "r-")
plt.xlabel("X")
plt.ylabel("y")
plt.show()
